# %%
import pandas as pd
import numpy as np
import csv
import gzip
import re

# %%
import sys
if (sys.version_info > (3, 0)):
    import pickle as pkl
else: #Python 2.7 imports
    import cPickle as pkl

# %%
from keras.models import load_model
from keras.preprocessing import sequence
# Out:
# C:\Users\Aravindhan.Poopathy\AppData\Local\Continuum\anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
wholeInputDf = pd.read_csv('C:/Users/Aravindhan.Poopathy/OneDrive/Arav/Tickets/finalemail.csv')

# %%
testDf = wholeInputDf.head(5)
testDf
# Out:
#    Unnamed: 0       user-id     source-name  \
# 0           0  7.002914e+09           Email
# 1           1           NaN           Email
# 2           2           NaN           Email
# 3           3  7.003836e+09  Outbound Email
# 4           4           NaN           Email
#
#                                              Subject  \
# 0                                   You lost my cat!
# 1                            Need help with payments
# 2  Re: Acc. No: 00159568 - Your Electricity Readings
# 3  So Energy - Two Suppliers Billing Your Electri...
# 4                                         Lost email
#
#                                          description  priority priority-name  \
# 0  Dear Customer Relations,\r\r\n\r\r\n\r\r\nI re...       3.0          High
# 1                    Credit card failed.\r\r\n\r\r\n       3.0          High
# 2  Hi Shahid\r\r\n\r\r\n\r\r\nPlease would you ve...       1.0           Low
# 3  Good Afternoon Vicencio, \r\r\n   \r\r\n Thank...       1.0           Low
# 4  Hi\r\r\n\r\r\nYesterday Sunday 12 November you...       1.0           Low
#
#    st-survey-rating  sentiment
# 0             103.0          1
# 1             102.0          1
# 2             103.0          1
# 3             102.0          1
# 4             103.0          1

# %%
word2Idx_path = open("C:/Users/Aravindhan.Poopathy/OneDrive/Arav/Sentence_classic_new-master/Sentence_classic_new-master/code/soeMailData/pkl/word2Idx.pickle", "rb")
word2Idx = pkl.load(word2Idx_path)

# %%
loadedModel = load_model("C:/Users/Aravindhan.Poopathy/OneDrive/Arav/Sentence_classic_new-master/Sentence_classic_new-master/code/soeMailData/soemailModels/mailmodel1.h5")

# %%
def createtestMatrix(sentence, word2Idx):
    unknownIdx = word2Idx['UNKNOWN_TOKEN']
    paddingIdx = word2Idx['PADDING_TOKEN']    


    testMatrix = []
    unknownWordCount = 0
    wordCount = 0

    targetWordIdx = 0

    for word in sentence:
        wordCount += 1

        if word in word2Idx:
            wordIdx = word2Idx[word]
        elif word.lower() in word2Idx:
            wordIdx = word2Idx[word.lower()]
        else:
            wordIdx = unknownIdx
            unknownWordCount += 1
        testMatrix.append(wordIdx)
#     print("Unknown tokens in test_Text: %.2f%%" % (unknownWordCount/(float(wordCount))*100))

    return testMatrix

data = pkl.load(gzip.open("C:/Users/Aravindhan.Poopathy/OneDrive/Arav/Sentence_classic_new-master/Sentence_classic_new-master/code/soeMailData/pkl/maildata.pkl.gz","rb"))
print("data loaded!")

train_labels = data['train']['labels']
train_sentences = data['train']['sentences']

dev_labels = data['dev']['labels']
dev_sentences = data['dev']['sentences']

test_labels = data['test']['labels']
test_sentences = data['test']['sentences']

word_embeddings = data['wordEmbeddings']

# :: Find the longest sentence in our dataset ::
max_sentence_len = 0
for sentence in train_sentences + dev_sentences + test_sentences:
    max_sentence_len = max(len(sentence), max_sentence_len)

print("Longest sentence: %d" % max_sentence_len)

batch_size = 50
# Out:
# data loaded!
# Longest sentence: 4957

# %%
def sentiment(row):
    mail = row[4]
    mail = re.sub(r'[?|$|>|!|<|#|*|[|-|]|_', '', mail)
    mail = mail.replace('\ufeff','')
    mail = re.sub(r'[\w\.-]+@[\w\.-]+','',mail)
    mail = re.sub(r"http\S+",'',mail)
    mail = re.sub(r"[\d{1,2}\/\d{1,2}\/\d{4}]+",'',mail)
    mail = " ".join(filter(lambda x:x[0] not in ['@','!','#','*','&','/','\\','#','-'], mail.split()))
    
    
    
    finalTest_matrix = createtestMatrix(mail, word2Idx)

    testarray = np.array(finalTest_matrix)
    testarray = testarray.reshape(1,len(finalTest_matrix))

    testarray.tolist()
    
    result_X = sequence.pad_sequences(testarray, maxlen=max_sentence_len)

    result_y_pred = loadedModel.predict(result_X, batch_size=batch_size)

    senti = result_y_pred.ravel()
#     print (senti)
    
#     if(senti[0]>=0.65):
# #         print("The User is positive about: ", topicList)
#         return('Positive')
#     elif(senti[0]>=0.35 and senti[0]<0.65):
# #         print("The user is Neutral about: ", topicList)
#         return('Neutral')
#     else:
# #         print("The user is negative about: ", topicList)
#         return('negative')
    return(senti)

# %%
# testDf.apply(sentiment, axis=1)

# %%
wholeInputDf['sentiment'] = wholeInputDf.apply(sentiment, axis=1)

# %%
wholeInputDf
# Out:
#       Unnamed: 0       user-id     source-name  \
# 0              0  7.002914e+09           Email
# 1              1           NaN           Email
# 2              2           NaN           Email
# 3              3  7.003836e+09  Outbound Email
# 4              4           NaN           Email
# 5              5           NaN           Email
# 6              6           NaN           Email
# 7              7           NaN           Email
# 8              8           NaN           Email
# 9              9           NaN           Email
# 10            10           NaN           Email
# 11            11           NaN           Email
# 12            12           NaN           Email
# 13            13  7.003906e+09          Portal
# 14            14  7.003853e+09          Portal
# 15            15           NaN           Email
# 16            16           NaN           Email
# 17            17           NaN           Email
# 18            18  7.003862e+09          Portal
# 19            19           NaN           Email
# 20            20  7.003850e+09          Portal
# 21            21           NaN           Email
# 22            22           NaN           Email
# 23            23           NaN           Email
# 24            24           NaN           Email
# 25            25  7.003875e+09          Portal
# 26            26           NaN           Email
# 27            27  7.003847e+09          Portal
# 28            28           NaN           Email
# 29            29           NaN           Email
# ...          ...           ...             ...
# 4325        4325  7.007667e+09  Outbound Email
# 4326        4326           NaN  Outbound Email
# 4327        4327           NaN           Email
# 4328        4328  7.008080e+09          Portal
# 4329        4329           NaN           Email
# 4330        4330           NaN           Email
# 4331        4331           NaN           Email
# 4332        4332  7.007871e+09          Portal
# 4333        4333           NaN           Email
# 4334        4334  7.008100e+09  Outbound Email
# 4335        4335  7.007836e+09  Outbound Email
# 4336        4336  7.008103e+09  Outbound Email
# 4337        4337  7.005741e+09  Outbound Email
# 4338        4338  7.007613e+09          Portal
# 4339        4339  7.008080e+09  Outbound Email
# 4340        4340  7.006481e+09          Portal
# 4341        4341           NaN           Email
# 4342        4342  7.006795e+09          Portal
# 4343        4343           NaN           Email
# 4344        4344  7.007494e+09          Portal
# 4345        4345  7.003838e+09  Outbound Email
# 4346        4346           NaN           Email
# 4347        4347           NaN           Email
# 4348        4348  7.007489e+09          Portal
# 4349        4349           NaN           Email
# 4350        4350  7.005999e+09          Portal
# 4351        4351  7.003843e+09  Outbound Email
# 4352        4352  7.003850e+09  Outbound Email
# 4353        4353  7.003845e+09  Outbound Email
# 4354        4354  7.003905e+09  Outbound Email
#
#                                                 Subject  \
# 0                                      You lost my cat!
# 1                               Need help with payments
# 2     Re: Acc. No: 00159568 - Your Electricity Readings
# 3     So Energy - Two Suppliers Billing Your Electri...
# 4                                            Lost email
# 5                              RE: Increasing dd amount
# 6                                         tariff change
# 7                             RE: Your latest statement
# 8                                              Readings
# 9           Re: We've adjusted your Direct Debit amount
# 10                   Barclays have changed my Sort Code
# 11                         Re: SO Energy - Direct Debit
# 12    Re: I accidently gave wrong star review, what ...
# 13                               So Energy contact form
# 14                               So Energy contact form
# 15       Renewal/Potential increase in monthly payments
# 16                                         Moving House
# 17                                          Moving Home
# 18                               So Energy contact form
# 19                               Account number00175317
# 20                               So Energy contact form
# 21                                           Gas boiler
# 22             Re: So Energy: Submitting meter readings
# 23                              closing account balance
# 24                                              renewal
# 25                               So Energy contact form
# 26            Account: 00176233 URGENT ACTION REQUESTED
# 27                               So Energy contact form
# 28                              Account Number 00175644
# 29                                   Re: Metering Issue
# ...                                                 ...
# 4325  So Energy - Your Gas Supply Registration (Acco...
# 4326                          So Energy - Billing Query
# 4327                          Re: Your latest statement
# 4328                             So Energy contact form
# 4329                                           Discount
# 4330                                     Account 145040
# 4331                            Moving my supply to you
# 4332                             So Energy contact form
# 4333                  Re: Your So Energy online account
# 4334  So Energy - Gas Supply Registration Objection ...
# 4335  So Energy - Electricity registration (Account ...
# 4336                             So Energy - Final Bill
# 4337  SO ENERGY. Opening reads. Account number 00189749
# 4338                             So Energy contact form
# 4339       So Energy - Cancellation and Re-Registration
# 4340                             So Energy contact form
# 4341                                Re: Your Final Bill
# 4342                             So Energy contact form
# 4343                                       Smart meters
# 4344                             So Energy contact form
# 4345       So Energy - So Llama Rates and Referral Code
# 4346                                    Acc no 00196321
# 4347                         Contact From: David Ashton
# 4348                             So Energy contact form
# 4349                                  Account: 00199246
# 4350                             So Energy contact form
# 4351                   We're able to issue you a refund
# 4352                   We're able to issue you a refund
# 4353    SO ENERGY. Opening read Account number 00179257
# 4354          So Energy - Gas Meter Exchange - 00135420
#
#                                             description  priority  \
# 0     Dear Customer Relations,\r\r\n\r\r\n\r\r\nI re...       3.0
# 1                       Credit card failed.\r\r\n\r\r\n       3.0
# 2     Hi Shahid\r\r\n\r\r\n\r\r\nPlease would you ve...       1.0
# 3     Good Afternoon Vicencio, \r\r\n   \r\r\n Thank...       1.0
# 4     Hi\r\r\n\r\r\nYesterday Sunday 12 November you...       1.0
# 5     Thank you. Could i increase to £52 per month s...       1.0
# 6     Account No 00128947.  I am presently on Gorill...       1.0
# 7     I am unable to log on to my account and would ...       1.0
# 8     Hello\r\r\n\r\r\nThese are the readings God wh...       1.0
# 9     Could you please leave at £61 per month ? We'r...       1.0
# 10    Hi – I have just renewed with you for another ...       1.0
# 11                        Thank you. Amazing as always        1.0
# 12    Good afternoon Nilesh,\r\r\n\r\r\nThank you fo...       1.0
# 13    I have my renewal quote for next year but befo...       1.0
# 14    I want to reduce my monthly payments as I have...       1.0
# 15    I am due to renew on 27 Dec, and am very happy...       1.0
# 16    Hi So Energy,\r\r\n\r\r\n\r\r\n\r\r\nMy accoun...       1.0
# 17    Dear So Energy,\r\r\n\r\r\nWe will be moving t...       1.0
# 18    just submitted latest readings at 82409 elec /...       1.0
# 19    Dear Sir/Madam\r\r\n\r\r\nI would be obliged i...       1.0
# 20    Hello,\r\r\nMy account will be closing shortly...       1.0
# 21    \r\r\nCan you tell me if you have any informat...       1.0
# 22    \r\r\nHello. \r\r\nI submit below my meter rea...       1.0
# 23    Dear So Energy,\r\r\n\r\r\n\r\r\nthank you for...       1.0
# 24    Hi there\r\r\n\r\r\n\r\r\nAccount no:  0014753...       1.0
# 25    Account Number: 00131180\r\r\nHello, I was won...       1.0
# 26    Dear Sir\r\r\n\r\r\nRE: 44 Rosedale Rd Sheffie...       1.0
# 27    As an existing customer my Gecko dual tarriff ...       1.0
# 28    Hi\r\r\nI e mailed last week to let you know t...       1.0
# 29    Hi,\r\r\nPlease see attached this week's readi...       1.0
# ...                                                 ...       ...
# 4325  Good Morning Brian,     Thank you very much fo...       1.0
# 4326  Hello Ian,   Thanks for your email regarding b...       1.0
# 4327  Gas 221 electric 1297\r\r\n\r\r\nSent from my ...       1.0
# 4328  Hi. Do i need to contact my current supplier t...       1.0
# 4329  Hi just making an enquiry as to weather you do...       1.0
# 4330  \r\r\nAs requested a clearer photo of the mete...       1.0
# 4331  Hi,\r\r\n\r\r\n\r\r\nI have requested to switc...       1.0
# 4332  Hello,\r\r\n\r\r\nI’d like to add my wife to t...       1.0
# 4333  Welcome to So Energy - Create Your AccountDear...       4.0
# 4334  Hi Ian,       \r\r\n \r\r\nThank you very much...       1.0
# 4335  Hello David      I hope you are well.       As...       1.0
# 4336  Hello Daniella,     Thanks for your time on th...       1.0
# 4337  Hello Mary,     I am a member of the Operation...       1.0
# 4338  I am in the process of switching to your compa...       1.0
# 4339  Hello Richard,     Thanks for your time on the...       1.0
# 4340  Hello\r\r\nI have recently switched energy pro...       1.0
# 4341  Hi,\r\r\n\r\r\nThanks for the final bill.\r\r\...       4.0
# 4342  Hello\r\r\nI would like to change my direct de...       1.0
# 4343  Will you be fitting smart meters and if so whe...       1.0
# 4344  Hi I would like to change my DD date to the 15...       1.0
# 4345  Hello Judith,     Thanks for your time on the ...       1.0
# 4346  631 Bromford Lane B8 2EN.\r\r\nAuth for Samia ...       1.0
# 4347  Energy readings from David Ashton 1 Chartwell ...       1.0
# 4348     How often do I need to send you meter readings       1.0
# 4349  Account: 00199246\r\r\n\r\r\n \r\r\n\r\r\nI am...       1.0
# 4350  Please advise me of the start date and meter r...       1.0
# 4351  Hello Moremika, \r\r\n \r\r\n We have recently...       1.0
# 4352  Hello Andrew, \r\r\n \r\r\n We have recently r...       1.0
# 4353  Hello Alison,     I am a member of the Operati...       1.0
# 4354  Hello Mark,     I hope you are well.     We ha...       1.0
#
#      priority-name  st-survey-rating     sentiment
# 0             High             103.0    [0.955002]
# 1             High             102.0   [0.9440301]
# 2              Low             103.0  [0.95534354]
# 3              Low             102.0   [0.9570606]
# 4              Low             103.0  [0.95424885]
# 5              Low             103.0   [0.9556263]
# 6              Low             103.0  [0.95365775]
# 7              Low             102.0   [0.9525919]
# 8              Low             102.0   [0.9507764]
# 9              Low             103.0   [0.9571916]
# 10             Low             103.0  [0.95939153]
# 11             Low             103.0  [0.94572926]
# 12             Low             103.0  [0.95471686]
# 13             Low             103.0  [0.94730604]
# 14             Low             102.0   [0.9410764]
# 15             Low             103.0  [0.94806254]
# 16             Low             103.0     [0.95202]
# 17             Low             103.0   [0.9457497]
# 18             Low             103.0  [0.95198673]
# 19             Low             102.0  [0.95479137]
# 20             Low             102.0   [0.9502807]
# 21             Low             102.0  [0.95105386]
# 22             Low             102.0  [0.95739186]
# 23             Low             102.0   [0.9480603]
# 24             Low             103.0   [0.9516843]
# 25             Low             102.0    [0.953051]
# 26             Low             103.0  [0.95037395]
# 27             Low             102.0   [0.9564109]
# 28             Low             103.0  [0.95044184]
# 29             Low             102.0   [0.9544307]
# ...            ...               ...           ...
# 4325           Low             102.0   [0.9562882]
# 4326           Low             103.0   [0.9555474]
# 4327           Low             102.0   [0.9597344]
# 4328           Low             102.0   [0.9500043]
# 4329           Low             102.0  [0.94759035]
# 4330           Low             102.0   [0.9488915]
# 4331           Low             102.0   [0.9531921]
# 4332           Low             103.0   [0.9473701]
# 4333        Urgent             102.0  [0.95714235]
# 4334           Low             103.0    [0.951053]
# 4335           Low             103.0    [0.954208]
# 4336           Low             103.0   [0.9532319]
# 4337           Low             100.0   [0.9532302]
# 4338           Low             102.0  [0.94901896]
# 4339           Low             102.0   [0.9561817]
# 4340           Low             102.0   [0.9505898]
# 4341        Urgent             103.0   [0.9581594]
# 4342           Low             103.0  [0.94573903]
# 4343           Low             102.0   [0.9529581]
# 4344           Low             103.0  [0.94432575]
# 4345           Low             103.0  [0.95692986]
# 4346           Low             103.0   [0.9445196]
# 4347           Low             103.0   [0.9528333]
# 4348           Low             103.0   [0.9436822]
# 4349           Low             103.0  [0.95628583]
# 4350           Low             102.0   [0.9481747]
# 4351           Low             103.0  [0.95326704]
# 4352           Low             103.0   [0.9530784]
# 4353           Low             103.0    [0.952495]
# 4354           Low             103.0  [0.95386267]
#
# [4355 rows x 9 columns]

# %%
wholeInputDf['st-survey-rating'].unique()
# Out:
# array([ 103.,  102., -102.,  100., -103.])

# %%
wholeInputDf['sentiment'].unique()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-9e34eb18ca9b> in <module>()
# ----> 1 wholeInputDf['sentiment'].unique()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\series.py in unique(self)
#    1489         Categories (3, object): [a < b < c]
#    1490         """
# -> 1491         result = super(Series, self).unique()
#    1492
#    1493         if is_datetime64tz_dtype(self.dtype):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\base.py in unique(self)
#    1047         else:
#    1048             from pandas.core.algorithms import unique1d
# -> 1049             result = unique1d(values)
#    1050
#    1051         return result
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\algorithms.py in unique(values)
#     366
#     367     table = htable(len(values))
# --> 368     uniques = table.unique(values)
#     369     uniques = _reconstruct_data(uniques, dtype, original)
#     370
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.unique()
#
# TypeError: unhashable type: 'numpy.ndarray'
