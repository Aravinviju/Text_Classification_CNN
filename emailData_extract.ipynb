# %%
import pandas as pd
import pyodbc

# %%
import numpy as np

# %%
server= 'SOE-AWS-SQL-003'
db='soenergy'

conn = pyodbc.connect('DRIVER={SQL Server};SERVER=' + server + ';DATABASE=' + db + '; Trusted_Connection=yes')
sql = "SELECT *  FROM [freshdesk].[dbo].[freshdesk_users]"

customer = pd.io.sql.read_sql(sql, conn)
customer.tail(5)
# Out:
#                id junifer_account                  name  \
# 89489  7003866612          153238       Sandra Mcintosh
# 89490  7003866613          151621  Marta Farre belmonte
# 89491  7003866614          149504       Andrew Ogbourne
# 89492  7003866615          167577     Christopher Franz
# 89493  7003866616          166282           Stephen Lau
#
#                               email     forename         surname active  \
# 89489  sandramcintosh88@hotmail.com       Sandra        Mcintosh   true
# 89490      mfarrebelmonte@gmail.com        Marta  Farre belmonte   true
# 89491  andrewogbourne@hotmail.co.uk       Andrew        Ogbourne   true
# 89492              chris@cfranz.com  Christopher           Franz   true
# 89493          stephen@swklau.co.uk      Stephen             Lau   true
#
#       address direct_debit_amount enrolment_source         ...          \
# 89489    None                  95             None         ...
# ...

# %%
import csv

# %%
# with open('C:/Users/Aravindhan.Poopathy/OneDrive/Arav/freshdesk_emails.csv', newline='') as f:
#     reader = csv.reader(f)

emails = pd.read_csv('C:/Users/Aravindhan.Poopathy/OneDrive/Arav/freshdesk_emails.csv')
emails
# Out:
#       id  ticket_id     user-id        updated-at            to_email  \
# 0      0          1  7002913902  24/10/2017 09:57                 NaN
# 1      1          1  7002913902  02/08/2017 17:13                 NaN
# 2      2          3  7003013283  24/10/2017 09:57                 NaN
# 3      8         61  7002921016  24/10/2017 13:50                 NaN
# 4      9         61  7002921016  24/10/2017 13:50                 NaN
# 5     10         61  7002921016  24/10/2017 13:51                 NaN
# 6     12         62  7002921016  24/10/2017 13:51                 NaN
# 7     14         63  7002921016  24/10/2017 13:51                 NaN
# 8     16         64  7002921016  24/10/2017 13:51                 NaN
# 9     18         65  7002921016  24/10/2017 13:51                 NaN
# 10    20         66  7002921016  24/10/2017 13:51                 NaN
# 11    22         67  7002921016  24/10/2017 13:51                 NaN
# ...

# %%
# emails['user-id']==7002913902

# %%
# customer['id'] == '7003866610'

# %%
emails.dtypes
# Out:
# id                                      int64
# ticket_id                               int64
# user-id                                 int64
# updated-at                             object
# to_email                               object
# support-email                          object
# Subject                                object
# requester-name                         object
# responder-name                         object
# created-at                             object
# Level 2                                object
# group                                  object
# deleted                                  bool
# delta                                  object
# description                            object
# dirty                                 float64
# due-by                                 object
# email-config-id                       float64
# fr-escalated                           object
# frdueby                                object
# ...

# %%
emails = emails.astype(str)
# emails

# %%
merged = pd.merge(customer, emails, left_on = 'id', right_on = 'user-id', how='inner', suffixes=('_customertable', '_email'))

# %%
with pd.option_context('display.max_rows', 50, 'display.max_columns', None):
    display(merged)
# Out:
#     id_customertable junifer_account                name  \
# 0         7002913902            None          James Dean
# 1         7002913902            None          James Dean
# 2         7002921016            None             Charlie
# 3         7002921016            None             Charlie
# 4         7002921016            None             Charlie
# 5         7002921016            None             Charlie
# 6         7002921016            None             Charlie
# 7         7002921016            None             Charlie
# 8         7002921016            None             Charlie
# 9         7002921016            None             Charlie
# 10        7002921016            None             Charlie
# 11        7002921016            None             Charlie
# 12        7002921016            None             Charlie
# 13        7002921016            None             Charlie
# 14        7002921016            None             Charlie
# ...

# %%
merged.to_csv('C:/Users/Aravindhan.Poopathy/OneDrive/Arav/final_Email.csv')

# %%
#----------------------------------------------------------Actual Code Starts here:

# %%
###### new emails with labels

new_emails = pd.read_csv("C:/Users/Aravindhan.Poopathy/OneDrive - So Energy/Arav/Tickets/all_tickets_shortened.csv",low_memory=False)

# %%
# new_emails['source-name']

# %%
# new_emails.astype('object')
# new_emails.dtypes
# new_emails['st-survey-rating']

# %%
# sample_new_emails = new_emails[:50]

# %%
# sample_new_emails.to_csv('C:/Users/Aravindhan.Poopathy/OneDrive/Arav/Tickets/sample_all_tickets.csv')

# %%
# emails = pd.read_csv("C:/Users/Aravindhan.Poopathy/OneDrive/Arav/Tickets/sample_all_tickets.csv", encoding='utf-8')

# %%
# new_emails[new_emails['source-name']!='Phone']

# %%
with pd.option_context('display.max_rows', 50, 'display.max_columns', None):

    display(new_emails[~new_emails['description'].isna()])
# Out:
#         Unnamed: 0      id  ticket_id       user-id           updated-at  \
# 0                0       0          1  7.002914e+09  2017-10-24 09:57:56
# 2                2       2          3  7.003013e+09  2017-10-24 09:57:53
# 3                3       3          7           NaN  2017-09-13 11:28:49
# 4                4       4         25           NaN  2017-10-24 09:57:29
# 7                7       7         61           NaN  2017-11-01 17:40:18
# 11              11      11         62           NaN  2017-10-24 13:51:04
# 13              13      13         63           NaN  2017-10-24 13:51:06
# 15              15      15         64           NaN  2017-10-24 13:51:07
# 17              17      17         65           NaN  2017-10-24 13:51:08
# 19              19      19         66           NaN  2017-10-24 13:51:08
# 21              21      21         67           NaN  2017-10-24 13:51:10
# 23              23      23         68           NaN  2017-11-01 17:40:16
# ...

# %%
Mask = ((new_emails['source-name']!='Phone') &
                     (~new_emails['Subject'].isna()) & 
                     (~new_emails['description'].isna()) & 
                     (~new_emails['st-survey-rating'].isna()))

# %%
# Mask
# Test = new_emails.loc[Mask, ['source-name','Subject','description','st-survey-rating']]
# Test[(Test['st-survey-rating'].isna())]
# new_emails.dtypes

# %%
finalDf = new_emails.loc[Mask, ['user-id','source-name','Subject','description','priority','priority-name','st-survey-rating']]

# %%
finalDf.reset_index(drop=True,inplace=True)

# %%
# Mask1 = ((finalDf['st-survey-rating'] ==103.0) | (finalDf['st-survey-rating'] == 102.0))
# Mask2 = (finalDf['st-survey-rating'] ==100.0)
# Mask3 = ((finalDf['st-survey-rating'] == -103.0) | (finalDf['st-survey-rating'] == -102.0))

# %%
Mask1 = (finalDf['st-survey-rating'] == 103.0) 
Mask2 = (finalDf['st-survey-rating'] == 102.0)
Mask3 = (finalDf['st-survey-rating'] == 100.0)
Mask4 = (finalDf['st-survey-rating'] == -103.0) 
Mask5 = (finalDf['st-survey-rating'] == -102.0)

# %%
# Mask2

# %%
finalDf['sentiment'] = np.nan

# %%
finalDf.loc[Mask1, 'sentiment'] = '0'

# %%
finalDf.loc[Mask2, 'sentiment'] = '1'

# %%
finalDf.loc[Mask3, 'sentiment'] = '2'

# %%
finalDf.loc[Mask4, 'sentiment'] = '3'

# %%
finalDf.loc[Mask5, 'sentiment'] = '4'

# %%
finalDf = finalDf[~(finalDf['sentiment'].isna())]
finalDf
# Out:
#            user-id     source-name  \
# 0     7.002914e+09           Email
# 1              NaN           Email
# 2              NaN           Email
# 3     7.003836e+09  Outbound Email
# 4              NaN           Email
# 5              NaN           Email
# 6              NaN           Email
# 7              NaN           Email
# 8              NaN           Email
# 9              NaN           Email
# 10             NaN           Email
# 11             NaN           Email
# 12             NaN           Email
# 13    7.003906e+09          Portal
# 14    7.003853e+09          Portal
# 15             NaN           Email
# 16             NaN           Email
# 17             NaN           Email
# 18    7.003862e+09          Portal
# 19             NaN           Email
# 20    7.003850e+09          Portal
# 21             NaN           Email
# 22             NaN           Email
# 23             NaN           Email
# 24             NaN           Email
# ...

# %%
finalDf['sentiment'].unique()
# Out:
# array(['0', '1', '4', '2', '3'], dtype=object)

# %%
finalDf[(finalDf['sentiment']=='4')].count()
# Out:
# user-id              50
# source-name         107
# Subject             107
# description         107
# priority            107
# priority-name       107
# st-survey-rating    107
# sentiment           107
# dtype: int64

# %%
finalDf.to_csv('C:/Users/Aravindhan.Poopathy/OneDrive - So Energy/Arav/Tickets/finalemail.csv')

# %%
import csv
import re
import email

# %%
#---------------------------------------TEST CELL



# # a = 'http://secure.teamhively.com/ratings/add/user/60998/rating/2[image: Unhappy] http://secure.teamhively.com/ratings/add/user/60998/rating/1\ufeff Click on a face to rate my performance http://secure.teamhively.com/ratings/new/user/60998 viju@gmail.com'
# # a = re.sub(r"http\S+",'',a)
# # a = re.sub(r'[\w\.-]+@[\w\.-]+','',a)
# # a

# a = '/uvuifnv \\ujsfnjf viju 21/3/2006 24/05/2007 \ufeff \ufeff \ufeff \ufeff'
# # a = " ".join(filter(lambda x:x[0] not in ['@','!','#','*','&','/','\\'], a.split()))
# a = re.sub(r"[\d{1,2}\/\d{1,2}\/\d{4}]+",'',a)
# a = a.replace("\ufeff",'')



# # b = email.message_from_string(a)
# # if b.is_multipart():
# #     for payload in b.get_payload():
# #         # if payload.is_multipart(): ...
# #         print(payload.get_payload())
# # else:
# #     print(b.get_payload())

# import email
# raw_message = """<div>Hi Cassie, my direct debit has increased to Â£75 from Â£45. could you please check why this has happened as i haven't received word on this increase. I will take some meter readings when i get home and send them to you so that a comparison can be made.</div>
# """
# msg = email.message_from_string(raw_message)
# for part in msg.walk():
#     # each part is a either non-multipart, or another multipart message
#     # that contains further parts... Message is organized like a tree
#     if part.get_content_type() == 'text/plain':
#         print (part.get_payload()) # prints the raw text

# with open('C:/Users/Aravindhan.Poopathy/OneDrive/Arav/Tickets/finalemail.csv', newline = '', encoding="utf8") as File:    
#     read = csv.reader(File)
#     trainList1=[]
#     for r in read:
# # #         print(r[5])
#         row1 = r[8]
#         row2 = r[4]
# #         row2 = row2.replace('P.S. This is a sample email that’s been converted into a ticket by Freshdesk. See how you can start converting email from customers into tickets in your helpdesk.','')
# #         row2 = row2.replace('P.S. How long until we get smart meters?','')
# # #         row2 = 
# #         row2 = re.sub(r"\ Get in touch: .+ All rights reserved.",'',row2)

        
#         row = row1+ "\t" +row2.strip()
#         trainList1.append(row)
# del trainList1[0]

# trainList1


# def writeFile(filename, sentences):
#         with open(filename, 'w', encoding='utf-8') as fOut:
#             for line in sentences:
#                 fOut.write(line)
#                 fOut.write("\n")
            
# writeFile("C:/Users/Aravindhan.Poopathy/OneDrive/testmail.txt", trainList1)


x = "I have decided not to leave .. and will continue with yor service.I would appreciate you note my next meter reading and reflect a sensible monthly debit amount.Regards. Sent from Samsung tablet Original message From: So Energy Date: :  To: Subject: We're sorry that you're leaving Hello JOHN We're sorry that you're leaving Account Number: We’ve been notified that you have requested to switch away from us. We operate a Low Price Policy ensuring that our one fixed tariff is always one of the best value for money tariffs available. Our latest tariff is called So Lion Gas if you’d prefer to stay with us and switch over to this tariff please get in touch immediately. A few things that make us different... % renewable energy We are proud that % of the electricity we supply is from renewable sources and at no extra cost. We've partnered with generators from across Great Britain so we can provide our customers with green energy. Take a look at where your electricity comes from. Choose where your energy comes from We're the only energy supplier that lets you decide where we source your renewable electricity from. Being one of our customers means you can vote your favourite renewable energy source and the results will decide our electricity fuel mix each year. Vote for your favourite energy source. If you still want to leave us If you still want to leave us we’re sorry that we weren’t what you were looking for. We would really like to know why it didn’t work out as we're always looking for ways in which to improve our service so drop us an email at Please remember not to cancel your Direct Debit until your final bill has been settled. If you're in credit then we will need to refund you via your Direct Debit or take a further payment if you have an outstanding balance. You didn’t switch away or want us to stop the switch If you didnt switch away please reply to this email immediately. There may be another energy supplier attempting to take over your supply by mistake industry jargon refer to this as an 'Erroneous Transfer'. We’ve put together a guide to explain what may be happening and what to do about it in our Erroneous Transfers Guide. Thanks The So Energy Team"
# x = x.replace(x,'')
x = re.sub(r"\Sent from.+To: Subject:","",x)

print(x)


# x = "ajsbdbjawbvj this is a test for removing till helpdesk viju"
# # x = x.replace(x,'')
# x = re.sub(r"\ this.+helpdesk",'',x)

# print(x)
# Out:
# I have decided not to leave .. and will continue with yor service.I would appreciate you note my next meter reading and reflect a sensible monthly debit amount.Regards.  We're sorry that you're leaving Hello JOHN We're sorry that you're leaving Account Number: We’ve been notified that you have requested to switch away from us. We operate a Low Price Policy ensuring that our one fixed tariff is always one of the best value for money tariffs available. Our latest tariff is called So Lion Gas if you’d prefer to stay with us and switch over to this tariff please get in touch immediately. A few things that make us different... % renewable energy We are proud that % of the electricity we supply is from renewable sources and at no extra cost. We've partnered with generators from across Great Britain so we can provide our customers with green energy. Take a look at where your electricity comes from. Choose where your energy comes from We're the only energy supplier that lets you decide where
# ...

# %%
#########################------------------------------making data ready in txt for training the deep learning the model

with open('C:/Users/Aravindhan.Poopathy/OneDrive/Arav/Tickets/finalemail.csv', newline = '', encoding="utf8") as File:    
    read = csv.reader(File)
    trainList1=[]
    for r in read:
#         print(r[4])
        row1 = r[8]
        row2 = re.sub(r'[?|$|>|!|<|#|*|[|-|]|_|�|//|\\', '', r[4])
        row2 = row2.replace('\ufeff','')
        row2 = re.sub(r'[\w\.-]+@[\w\.-]+','',row2)
        row2 = re.sub(r"http\S+",'',row2)
        row2 = re.sub(r"[\d{1,2}\/\d{1,2}\/\d{4}]+",'',row2)
        row2 = " ".join(filter(lambda x:x[0] not in ['@','!','*','&','/','\\','#','-','='], row2.split()))
        row2 = re.sub(r'\ P.S. .+ smart meters','',row2)
        row2 = re.sub(r'\ P.S. This is a sample email .+ helpdesk','',row2)
        row2 = re.sub(r'\ Get in touch: .+ All rights reserved.','',row2)
        row2 = re.sub(r'\ This message contains confidential information.+may not be attributed to So Energy.', '', row2)
        row2 = re.sub(r'\ This message contains confidential information.+a hard-copy version', '', row2)
        row2 = re.sub(r'\ This message contains confidential information.+','',row2)
        row2 = re.sub(r'\ message contains confidential.+','', row2)
        row2 = re.sub(r'\ So Energy Trading Limited.+','',row2)
        row2 = re.sub(r'\ Like us on.+','',row2)
        row2 = re.sub(r'\ Thanks The So Energy TeamLike.+','',row2)
        row2 = re.sub(r'\sent from my.+','', row2)
        row2 = re.sub(r'\ So Energy wrote:.+text-decoration:underline;yiv','',row2)
        row2 = re.sub(r'\ So Energy wrote:.+All rights reserved.','',row2)
        row2 = re.sub(r'\ So wrote:.+All rights reserved.','',row2)
        row2 = re.sub(r'\ So Energyyiv.+acolor:fcd;font-weight:normal;text-decoration:underline;yiv','',row2)
        row2 = re.sub(r'\So Energy wrote.+text-decoration:underline; yiv ','',row2)
        row2 = re.sub(r"\bwww.+","",row2)
        row2 = re.sub(r"\So Energy p margin:px.+text-decoration:underline;","",row2)
        row2 = re.sub(r"\(.+\)","",row2)
        row2 = re.sub("\{.+\}","",row2)
        row2 = re.sub(r"\.yivReadMsgBody.+collapse;yiv","",row2)
        row2 = re.sub(r"\Sent from.+A;padding:px;border-radius:px;background-color:A;yiv","",row2)
        row2 = re.sub(r"\Sent from.+pmargin-top:px;margin-bottom:px;","",row2)
        row2 = re.sub(r"\Sent from.+To: Subject:","",row2)
        
        
        
        
        row = row1+ "\t" +row2.strip()
        trainList1.append(row)
del trainList1[0]
# Out:
# description
# Dear Customer Relations,
#
#
# I recently flew Upper Class from Heathrow to JFK and whilst some bits were great,one bit in particular was really really bad.I flew with my cat* and you froze** it and it died*** which made me sad****.
#
#
# * I use the word 'cat' in the sense of 'suitcase'.
# ** I use the word 'froze' in the sense of 'lost'.
# *** I use the word 'died' in the sense of 'didn't turn up for 2 days'.
# **** I use the word 'sad' correctly.
#
#
# We all lose things. I once went for a pint with the late Keith Floyd and he lost an entire week.Another time I worked out an equation for cold fusion and gave it to my cat on a memory stick,which she lost. Keith Floyd, me, my cat, and you are all only human, so these things happen.What separates humans from super humans is the way they deal with these hiccups.
#
#
# I won't bore you with the details. The only question is how can we make it right?
#
#
# Yours ever,
# James Dean
#
# -------------------------------
#
# ...

# %%
#Goodsamples increased:

goodsenti = []
# textfile = 'C:/Users/Aravindhan.Poopathy/OneDrive/Arav/Sentence_classic_new-master/Sentence_classic_new-master/code/data/twitterTrianData.txt'

for line in trainList1:
    if line[0]=='1':
#         line = line.strip()
        goodsenti.append(line)

goodtest = goodsenti
len(goodtest)
# goodsenti

for i in range(1):
    goodtest = goodtest + goodtest

len(goodtest)
# Out:
# 2954

# %%
#Averagesamples increased;

avgsenti = []
# textfile = 'C:/Users/Aravindhan.Poopathy/OneDrive/Arav/Sentence_classic_new-master/Sentence_classic_new-master/code/data/twitterTrianData.txt'

for line in trainList1:
    if line[0]=='2':
#         line = line.strip()
        avgsenti.append(line)

avgtest = avgsenti
len(avgtest)

for i in range(4):
    avgtest = avgtest + avgtest

len(avgtest)
# Out:
# 3408

# %%
#Badsamples increased;

Badsenti = []
# textfile = 'C:/Users/Aravindhan.Poopathy/OneDrive/Arav/Sentence_classic_new-master/Sentence_classic_new-master/code/data/twitterTrianData.txt'

for line in trainList1:
    if line[0]=='3':
#         line = line.strip()
        Badsenti.append(line)

Badtest = Badsenti
len(Badtest)

for i in range(5):
    Badtest = Badtest + Badtest

len(Badtest)
# Out:
# 2048

# %%
#Badsamples increased;

Terriblesenti = []
# textfile = 'C:/Users/Aravindhan.Poopathy/OneDrive/Arav/Sentence_classic_new-master/Sentence_classic_new-master/code/data/twitterTrianData.txt'

for line in trainList1:
    if line[0]=='4':
#         line = line.strip()
        Terriblesenti.append(line)

Terribletest = Terriblesenti
len(Terribletest)

for i in range(5):
    Terribletest = Terribletest + Terribletest

len(Terribletest)
# Out:
# 3424

# %%
mergedlist = trainList1
mergedlist
# Out:
# ["0\tDear Customer Relations I recently flew Upper Class from Heathrow to JFK and whilst some bits were greatone bit in particular was really really bad.I flew with my cat and you froze it and it died which made me sad. I use the word 'cat' in the sense of 'suitcase'. I use the word 'froze' in the sense of 'lost'. I use the word 'died' in the sense of 'didn't turn up for days'. I use the word 'sad' correctly. We all lose things. I once went for a pint with the late Keith Floyd and he lost an entire week.Another time I worked out an equation for cold fusion and gave it to my cat on a memory stickwhich she lost. Keith Floyd me my cat and you are all only human so these things happen.What separates humans from super humans is the way they deal with these hiccups. I won't bore you with the details. The only question is how can we make it right Yours ever James Dean.",
#  '1\tCredit card failed.',
# ...

# %%
mergedlist = mergedlist + goodtest + avgtest + Badtest + Terribletest

# %%
len(mergedlist)
# Out:
# 16189

# %%
def writeFile(filename, sentences):
        with open(filename, 'w', encoding='utf-8') as fOut:
            for line in sentences:
                fOut.write(line)
                fOut.write("\n")
writeFile("C:/Users/Aravindhan.Poopathy/OneDrive - So Energy/Arav/Sentence_classic_new-master/Sentence_classic_new-master/code/soeMailData/finalmaildata.txt", mergedlist)

# %%
from random import shuffle
shuffle(mergedlist)
    
n = len(mergedlist)    
trainSplit = (0, int(0.5*n))
devSplit = (trainSplit[1], trainSplit[1]+int(0.25*n))
testSplit = (devSplit[1], n)

train = mergedlist[trainSplit[0]:trainSplit[1]]
dev = mergedlist[devSplit[0]:devSplit[1]]
test = mergedlist[testSplit[0]:testSplit[1]]

writeFile('C:/Users/Aravindhan.Poopathy/OneDrive - So Energy/Arav/Sentence_classic_new-master/Sentence_classic_new-master/code/soeMailData/mailtrain.txt', train)
writeFile('C:/Users/Aravindhan.Poopathy/OneDrive - So Energy/Arav/Sentence_classic_new-master/Sentence_classic_new-master/code/soeMailData/maildev.txt', dev)
writeFile('C:/Users/Aravindhan.Poopathy/OneDrive - So Energy/Arav/Sentence_classic_new-master/Sentence_classic_new-master/code/soeMailData/mailtest.txt', test)
